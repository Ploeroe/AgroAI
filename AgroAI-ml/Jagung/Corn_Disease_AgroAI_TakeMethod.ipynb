# %% [markdown]
# # Corn Disease Prediction for AgroAI
# ## Model 1: Convolutional Neural Network
# ### Import Dependencies

# %%
import tensorflow as tf
from PIL import Image
import cv2, pathlib, splitfolders
from tensorflow.keras.layers import *
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
import os
import shutil
import pickle
import tempfile
from sklearn.model_selection import train_test_split

# %%
import seaborn as sns

# %%
np.__version__
# Out:
# '1.23.5'

# %%
tf.__version__
# Out:
# '2.6.0'

# %%
physical_devices = tf.config.experimental.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# ### Load Images

# %%
IMAGE_SIZE = 256
TARGET_SIZE = (IMAGE_SIZE, IMAGE_SIZE)
INPUT_SHAPE = (IMAGE_SIZE, IMAGE_SIZE, 3)
CHANNELS = 3
BATCH_SIZE = 32
INPUT_SHAPE2 = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)

# %%
#def get_dataset_partitions_pd(df, train_split=0.8, val_split=0.1, test_split=0.1):
#    assert (train_split + test_split + val_split) == 1
#    
    # Only allows for equal validation and test splits
#    assert val_split == test_split

# %%
# Set up the base directory
base_dir = "./AgroAI/Corn_Edit"

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
            base_dir,
            labels = 'inferred',
            shuffle = True,
            image_size = (IMAGE_SIZE, IMAGE_SIZE),
            batch_size = BATCH_SIZE,
            color_mode = 'rgb'
)
# Out:
# Found 4311 files belonging to 4 classes.

# %%
type(dataset)
# Out:
# tensorflow.python.data.ops.dataset_ops.BatchDataset

# %%
#def resize_data(images, labels):
#    tf.print('Original shape -->', tf.shape(images))
#    SIZE = (224, 224)
#    return tf.image.resize(images, SIZE), labels

# %%
#dataset = dataset.map(resize_data)

# %%
classes = dataset.class_names
classes
# Out:
# ['corn Common Rust',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn healthy']

# %%
len(dataset)
# Out:
# 135

# %%
plt.figure(figsize=(10,10))
for image_batch , label_batch in dataset.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(image_batch[i].numpy().astype('uint8'))
        plt.title(classes[label_batch[i]])
        plt.axis('off')

# %%
len(dataset) * 64
# Out:
# 8640

# %% [markdown]
# ### Data Splitting

# %%
def data_split(data, train_split = 0.8, val_split = 0.15, 
               test_split = 0.05, shuffle=True, shuffle_size = 10000):
    data_size = len(data)
    if shuffle:
        data = data.shuffle(shuffle_size, seed=8)
    
    train_size = int(train_split * data_size)
    val_size = int(val_split * data_size)
    
    train_ds = data.take(train_size)
    val_ds = data.skip(train_size).take(val_size)
    test_ds = data.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = data_split(dataset)

# %%
print("Length of Training Dataset is",len(train_ds))
print("\nLength of Validation Dataset is",len(val_ds))
print("\nLength of Testing Dataset is",len(test_ds))
# Out:
# Length of Training Dataset is 108
#
# Length of Validation Dataset is 20
#
# Length of Testing Dataset is 7

# %% [markdown]
# ### Image Augmentation

# %% [markdown]
# Since ImageDataGenerator is deprecated as of Tensorflow >=2.5, we can use the Keras Layers Experimental Preprocessing API to apply the image augmentations instead.

# %%
train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
# Out:
# <PrefetchDataset shapes: ((None, 256, 256, 3), (None,)), types: (tf.float32, tf.int32)>

# %%
resizing_rescaling = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(224,224),
    tf.keras.layers.experimental.preprocessing.Rescaling(1.0/255.0)
])

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.4),
    tf.keras.layers.experimental.preprocessing.RandomZoom(height_factor=(-0.3, 0.3),
                                                                 width_factor=(-0.3, 0.3),
                                                                 fill_mode = 'nearest'),
    tf.keras.layers.experimental.preprocessing.RandomTranslation(height_factor=(-0.3, 0.3),
                                                                 width_factor=(-0.3, 0.3),
                                                                 fill_mode = 'nearest'),
    tf.keras.layers.experimental.preprocessing.RandomHeight(factor=(-0.3, 0.3),
                                                            interpolation = 'nearest'),
    tf.keras.layers.experimental.preprocessing.RandomContrast(0.9)
])

# %% [markdown]
# ### Init Methods

# %%
def conf_matrix(y_test, y_pred):
  cf_matrix = confusion_matrix(y_test, y_pred)

  ax = sns.heatmap(cf_matrix, annot=True, fmt='g', cmap='Blues')

  ax.set_title('Confusion Matrix with labels\n')
  ax.set_xlabel('\nPredicted Values')
  ax.set_ylabel('Actual Values ')
  ax.set_xticks()
  ax.xaxis.set_ticklabels(source_classes, rotation=45)
  ax.yaxis.set_ticklabels(source_classes, rotation=45)

  plt.show()

# %%
saved_model_dir = "saved_model"
saved_model_his = "saved_model_history"
tflite_model_dir = "tflite_model"

if not(os.path.isdir(saved_model_dir)): os.mkdir(saved_model_dir)
if not(os.path.isdir(saved_model_his)): os.mkdir(saved_model_his)
if not(os.path.isdir(tflite_model_dir)): os.mkdir(tflite_model_dir)

# %%
# save model method
def saved_model(modelname, model):
  export_path = os.path.join(saved_model_dir, modelname)
  if os.path.isdir(export_path):
    print('\nAlready saved a model, replace to new model\n')
    shutil.rmtree(export_path, ignore_errors=True)

  model.save(export_path)
  print("Export path: ", export_path)
  print(os.listdir(export_path))

# save model history method
def saved_model_history(modelname, history):
  with open(os.path.join(saved_model_his, modelname), 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %%
# convert saved model to TFLite model
def tflite_model_convert(modelname, tflitedir):
  # Intialize the TFLite converter to load the SavedModel
  export_path = os.path.join(saved_model_dir, modelname)

  converter = tf.lite.TFLiteConverter.from_saved_model(export_path)

  # Set the optimization strategy in the converter 
  converter.optimizations = [tf.lite.Optimize.DEFAULT]

  # Use the tool to finally convert the model
  tflite_model = converter.convert()

  # Write TFLite model
  tflite_dir = os.path.join(tflite_model_dir, tflitedir)

  if os.path.isdir(tflite_dir):
    print('\nAlready saved a model, replace to new model\n')
    shutil.rmtree(tflite_dir, ignore_errors=True)

  os.mkdir(tflite_dir)

  tflite_file = os.path.join(tflite_dir, "leaf_{}.tflite".format(tflitedir.lower()))
  label_file = os.path.join(tflite_dir, "leaf_{}.txt".format(tflitedir.lower()))

  with open(tflite_file, "wb") as f:
      f.write(tflite_model)

  with open(label_file, 'w') as f:
      f.write('\n'.join(name_classes))

  print("Export path: ", tflite_dir)
  print(os.listdir(tflite_dir))

# %%
# save all model with simplify function
def save_all_model(modelname, model, history):
  # save model
  saved_model(modelname, model)

  # save history as dict
  saved_model_history(modelname, history)

  # save best model
  #best_model = tf.keras.models.load_model('best_{}.h5'.format(modelname))
  #best_modelname = "BestMC_{}".format(modelname)
  #saved_model(best_modelname, best_model)
  # clear best model h5 format
 # os.remove('best_{}.h5'.format(modelname))

  # save tflite best model
  #tflite_model_convert(best_modelname, modelname)

# %% [markdown]
# ### Model 1: Convolutional Neural Network

# %%
n_classes = 4

model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=INPUT_SHAPE),
    resizing_rescaling,
    data_augmentation,
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(32, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(n_classes, activation='softmax')
])

model.build(input_shape=(None,) + INPUT_SHAPE)
model.output_shape
# Out:
# (None, 4)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 224, 224, 3)       0
# _________________________________________________________________
# sequential_1 (Sequential)    (None, None, 224, 3)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, None, 222, 32)     896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, None, 111, 32)     0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, None, 109, 32)     9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, None, 54, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, None, 52, 64)      18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, None, 26, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, None, 24, 64)      36928
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, None, 12, 64)      0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 64)                0
# _________________________________________________________________
# flatten (Flatten)            (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 512)               33280
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               65664
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 516
# =================================================================
# Total params: 165,028
# Trainable params: 165,028
# Non-trainable params: 0
# _________________________________________________________________

# %%
class EarlyStoppingAtMaxAccuracy(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs = {}):
        if(logs.get('accuracy')>=0.99):
            print("\nAccuracy is high so cancelling training!")
            self.model.stop_training = True

callbacks = EarlyStoppingAtMaxAccuracy()

lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.001,
    decay_steps=10000,
    decay_rate=0.9)

# %%
#model.compile(
#    optimizer=tf.keras.optimizers.Adam(learning_rate = lr_schedule),
#    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
#    metrics=['accuracy']
#)

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits = False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    batch_size=BATCH_SIZE,
    validation_data=val_ds,
    verbose=1,
    epochs=100,
    callbacks=[callbacks]
)
# Out:
# Epoch 1/100
# 108/108 [==============================] - 77s 451ms/step - loss: 1.1838 - accuracy: 0.4961 - val_loss: 0.9969 - val_accuracy: 0.5609
# Epoch 2/100
# 108/108 [==============================] - 21s 170ms/step - loss: 0.8265 - accuracy: 0.6408 - val_loss: 0.7088 - val_accuracy: 0.6875
# Epoch 3/100
# 108/108 [==============================] - 13s 98ms/step - loss: 0.6950 - accuracy: 0.6864 - val_loss: 0.7275 - val_accuracy: 0.6891
# Epoch 4/100
# 108/108 [==============================] - 11s 79ms/step - loss: 0.7030 - accuracy: 0.6849 - val_loss: 0.6676 - val_accuracy: 0.6844
# Epoch 5/100
# 108/108 [==============================] - 9s 66ms/step - loss: 0.7129 - accuracy: 0.6815 - val_loss: 0.7266 - val_accuracy: 0.6484
# Epoch 6/100
# 108/108 [==============================] - 9s 60ms/step - loss: 0.6575 - accuracy: 0.6963 - val_loss: 0.6209 - val_accuracy: 0.6891
# Epoch 7/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.6544 - accuracy: 0.6959 - val_loss: 0.5739 - val_accuracy: 0.7063
# Epoch 8/100
# 108/108 [==============================] - 9s 60ms/step - loss: 0.6061 - accuracy: 0.7035 - val_loss: 0.7370 - val_accuracy: 0.6938
# Epoch 9/100
# 108/108 [==============================] - 9s 60ms/step - loss: 0.6405 - accuracy: 0.7023 - val_loss: 0.5462 - val_accuracy: 0.7625
# Epoch 10/100
# 108/108 [==============================] - 9s 63ms/step - loss: 0.6013 - accuracy: 0.7151 - val_loss: 0.5062 - val_accuracy: 0.7338
# Epoch 11/100
# 108/108 [==============================] - 8s 59ms/step - loss: 0.5881 - accuracy: 0.7125 - val_loss: 0.4869 - val_accuracy: 0.7906
# Epoch 12/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.6062 - accuracy: 0.7299 - val_loss: 0.5690 - val_accuracy: 0.7375
# Epoch 13/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.6089 - accuracy: 0.7142 - val_loss: 0.5794 - val_accuracy: 0.6531
# Epoch 14/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.5831 - accuracy: 0.7392 - val_loss: 0.5027 - val_accuracy: 0.7813
# Epoch 15/100
# 108/108 [==============================] - 8s 57ms/step - loss: 0.5172 - accuracy: 0.7627 - val_loss: 0.4734 - val_accuracy: 0.7797
# Epoch 16/100
# 108/108 [==============================] - 8s 57ms/step - loss: 0.5758 - accuracy: 0.7380 - val_loss: 0.4657 - val_accuracy: 0.7937
# Epoch 17/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.5435 - accuracy: 0.7607 - val_loss: 0.5078 - val_accuracy: 0.7563
# Epoch 18/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.5603 - accuracy: 0.7454 - val_loss: 0.4531 - val_accuracy: 0.8035
# Epoch 19/100
# 108/108 [==============================] - 8s 57ms/step - loss: 0.5508 - accuracy: 0.7560 - val_loss: 0.4882 - val_accuracy: 0.7594
# Epoch 20/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.5422 - accuracy: 0.7644 - val_loss: 0.4334 - val_accuracy: 0.7984
# Epoch 21/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.5333 - accuracy: 0.7656 - val_loss: 0.5578 - val_accuracy: 0.6859
# Epoch 22/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.5047 - accuracy: 0.7813 - val_loss: 0.5133 - val_accuracy: 0.7578
# Epoch 23/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.5073 - accuracy: 0.7775 - val_loss: 0.4617 - val_accuracy: 0.7971
# Epoch 24/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.5030 - accuracy: 0.7813 - val_loss: 0.4029 - val_accuracy: 0.8344
# Epoch 25/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.4816 - accuracy: 0.7908 - val_loss: 0.3870 - val_accuracy: 0.8336
# Epoch 26/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.5041 - accuracy: 0.7827 - val_loss: 0.4892 - val_accuracy: 0.7563
# Epoch 27/100
# 108/108 [==============================] - 8s 51ms/step - loss: 0.4928 - accuracy: 0.7786 - val_loss: 0.3660 - val_accuracy: 0.8384
# Epoch 28/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.4601 - accuracy: 0.7958 - val_loss: 0.4200 - val_accuracy: 0.8062
# Epoch 29/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.4470 - accuracy: 0.8128 - val_loss: 0.3969 - val_accuracy: 0.8453
# Epoch 30/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.4640 - accuracy: 0.8071 - val_loss: 0.4567 - val_accuracy: 0.7953
# Epoch 31/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.4756 - accuracy: 0.7926 - val_loss: 0.4407 - val_accuracy: 0.8156
# Epoch 32/100
# 108/108 [==============================] - 8s 51ms/step - loss: 0.4277 - accuracy: 0.8197 - val_loss: 0.3249 - val_accuracy: 0.8687
# Epoch 33/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.4522 - accuracy: 0.8160 - val_loss: 0.4071 - val_accuracy: 0.8219
# Epoch 34/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.4503 - accuracy: 0.8113 - val_loss: 0.3486 - val_accuracy: 0.8641
# Epoch 35/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.4490 - accuracy: 0.8138 - val_loss: 0.3340 - val_accuracy: 0.8594
# Epoch 36/100
# 108/108 [==============================] - 8s 51ms/step - loss: 0.4152 - accuracy: 0.8213 - val_loss: 0.3076 - val_accuracy: 0.8687
# Epoch 37/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.4362 - accuracy: 0.8242 - val_loss: 0.3460 - val_accuracy: 0.8469
# Epoch 38/100
# 108/108 [==============================] - 8s 51ms/step - loss: 0.4236 - accuracy: 0.8241 - val_loss: 0.3067 - val_accuracy: 0.8641
# Epoch 39/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.4321 - accuracy: 0.8167 - val_loss: 0.3581 - val_accuracy: 0.8359
# Epoch 40/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3991 - accuracy: 0.8375 - val_loss: 0.2886 - val_accuracy: 0.8875
# Epoch 41/100
# 108/108 [==============================] - 8s 51ms/step - loss: 0.4278 - accuracy: 0.8181 - val_loss: 0.3681 - val_accuracy: 0.8484
# Epoch 42/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.3997 - accuracy: 0.8299 - val_loss: 0.3396 - val_accuracy: 0.8516
# Epoch 43/100
# 108/108 [==============================] - 8s 57ms/step - loss: 0.4203 - accuracy: 0.8213 - val_loss: 0.2719 - val_accuracy: 0.8764
# Epoch 44/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.4019 - accuracy: 0.8325 - val_loss: 0.3265 - val_accuracy: 0.8516
# Epoch 45/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.4209 - accuracy: 0.8183 - val_loss: 0.3213 - val_accuracy: 0.8422
# Epoch 46/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3631 - accuracy: 0.8486 - val_loss: 0.2984 - val_accuracy: 0.8750
# Epoch 47/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.4160 - accuracy: 0.8210 - val_loss: 0.3821 - val_accuracy: 0.8241
# Epoch 48/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.3476 - accuracy: 0.8587 - val_loss: 0.2888 - val_accuracy: 0.8813
# Epoch 49/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.4057 - accuracy: 0.8274 - val_loss: 0.2961 - val_accuracy: 0.8703
# Epoch 50/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3794 - accuracy: 0.8393 - val_loss: 0.3207 - val_accuracy: 0.8811
# Epoch 51/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3846 - accuracy: 0.8440 - val_loss: 0.2847 - val_accuracy: 0.8969
# Epoch 52/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.3854 - accuracy: 0.8370 - val_loss: 0.2587 - val_accuracy: 0.9062
# Epoch 53/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.3777 - accuracy: 0.8436 - val_loss: 0.2877 - val_accuracy: 0.9047
# Epoch 54/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3748 - accuracy: 0.8490 - val_loss: 0.4151 - val_accuracy: 0.8172
# Epoch 55/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3742 - accuracy: 0.8538 - val_loss: 0.2322 - val_accuracy: 0.9078
# Epoch 56/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3625 - accuracy: 0.8491 - val_loss: 0.2745 - val_accuracy: 0.8891
# Epoch 57/100
# 108/108 [==============================] - 8s 52ms/step - loss: 0.3787 - accuracy: 0.8439 - val_loss: 0.2681 - val_accuracy: 0.8797
# Epoch 58/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.3782 - accuracy: 0.8428 - val_loss: 0.2073 - val_accuracy: 0.9234
# Epoch 59/100
# 108/108 [==============================] - 8s 58ms/step - loss: 0.3479 - accuracy: 0.8607 - val_loss: 0.2710 - val_accuracy: 0.8859
# Epoch 60/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3519 - accuracy: 0.8570 - val_loss: 0.2346 - val_accuracy: 0.9016
# Epoch 61/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3554 - accuracy: 0.8503 - val_loss: 0.2321 - val_accuracy: 0.9156
# Epoch 62/100
# 108/108 [==============================] - 8s 53ms/step - loss: 0.3628 - accuracy: 0.8576 - val_loss: 0.2850 - val_accuracy: 0.8609
# Epoch 63/100
# 108/108 [==============================] - 8s 58ms/step - loss: 0.3365 - accuracy: 0.8607 - val_loss: 0.2402 - val_accuracy: 0.9203
# Epoch 64/100
# 108/108 [==============================] - 9s 59ms/step - loss: 0.3406 - accuracy: 0.8532 - val_loss: 0.2117 - val_accuracy: 0.9109
# Epoch 65/100
# 108/108 [==============================] - 9s 61ms/step - loss: 0.3554 - accuracy: 0.8480 - val_loss: 0.2664 - val_accuracy: 0.8906
# Epoch 66/100
# 108/108 [==============================] - 9s 59ms/step - loss: 0.3346 - accuracy: 0.8706 - val_loss: 0.2655 - val_accuracy: 0.8906
# Epoch 67/100
# 108/108 [==============================] - 9s 61ms/step - loss: 0.3383 - accuracy: 0.8616 - val_loss: 0.1956 - val_accuracy: 0.9266
# Epoch 68/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3156 - accuracy: 0.8712 - val_loss: 0.2389 - val_accuracy: 0.8938
# Epoch 69/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.3127 - accuracy: 0.8686 - val_loss: 0.1940 - val_accuracy: 0.9234
# Epoch 70/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.3266 - accuracy: 0.8668 - val_loss: 0.2508 - val_accuracy: 0.8922
# Epoch 71/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.2961 - accuracy: 0.8848 - val_loss: 0.2635 - val_accuracy: 0.8906
# Epoch 72/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3263 - accuracy: 0.8634 - val_loss: 0.2639 - val_accuracy: 0.8859
# Epoch 73/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3070 - accuracy: 0.8753 - val_loss: 0.2247 - val_accuracy: 0.9113
# Epoch 74/100
# 108/108 [==============================] - 9s 58ms/step - loss: 0.2991 - accuracy: 0.8796 - val_loss: 0.2415 - val_accuracy: 0.9078
# Epoch 75/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.3161 - accuracy: 0.8770 - val_loss: 0.2664 - val_accuracy: 0.8984
# Epoch 76/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3169 - accuracy: 0.8721 - val_loss: 0.1921 - val_accuracy: 0.9328
# Epoch 77/100
# 108/108 [==============================] - 9s 59ms/step - loss: 0.3221 - accuracy: 0.8657 - val_loss: 0.3525 - val_accuracy: 0.8219
# Epoch 78/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.3305 - accuracy: 0.8645 - val_loss: 0.2005 - val_accuracy: 0.9219
# Epoch 79/100
# 108/108 [==============================] - 9s 59ms/step - loss: 0.3207 - accuracy: 0.8724 - val_loss: 0.2026 - val_accuracy: 0.9125
# Epoch 80/100
# 108/108 [==============================] - 8s 57ms/step - loss: 0.3303 - accuracy: 0.8651 - val_loss: 0.2589 - val_accuracy: 0.8875
# Epoch 81/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.2681 - accuracy: 0.8929 - val_loss: 0.2800 - val_accuracy: 0.8891
# Epoch 82/100
# 108/108 [==============================] - 9s 62ms/step - loss: 0.2872 - accuracy: 0.8854 - val_loss: 0.2914 - val_accuracy: 0.8672
# Epoch 83/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3637 - accuracy: 0.8564 - val_loss: 0.2047 - val_accuracy: 0.9109
# Epoch 84/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.2921 - accuracy: 0.8837 - val_loss: 0.2237 - val_accuracy: 0.9156
# Epoch 85/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3223 - accuracy: 0.8707 - val_loss: 0.1650 - val_accuracy: 0.9422
# Epoch 86/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.2597 - accuracy: 0.8999 - val_loss: 0.2043 - val_accuracy: 0.9141
# Epoch 87/100
# 108/108 [==============================] - 8s 54ms/step - loss: 0.2836 - accuracy: 0.8793 - val_loss: 0.1917 - val_accuracy: 0.9234
# Epoch 88/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3044 - accuracy: 0.8761 - val_loss: 0.1801 - val_accuracy: 0.9391
# Epoch 89/100
# 108/108 [==============================] - 9s 58ms/step - loss: 0.2915 - accuracy: 0.8863 - val_loss: 0.2107 - val_accuracy: 0.9078
# Epoch 90/100
# 108/108 [==============================] - 9s 58ms/step - loss: 0.2734 - accuracy: 0.8886 - val_loss: 0.1667 - val_accuracy: 0.9422
# Epoch 91/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.2766 - accuracy: 0.8889 - val_loss: 0.2327 - val_accuracy: 0.9172
# Epoch 92/100
# 108/108 [==============================] - 9s 60ms/step - loss: 0.2942 - accuracy: 0.8787 - val_loss: 0.1774 - val_accuracy: 0.9359
# Epoch 93/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.2820 - accuracy: 0.8874 - val_loss: 0.1811 - val_accuracy: 0.9234
# Epoch 94/100
# 108/108 [==============================] - 9s 58ms/step - loss: 0.3081 - accuracy: 0.8796 - val_loss: 0.2048 - val_accuracy: 0.9160
# Epoch 95/100
# 108/108 [==============================] - 9s 58ms/step - loss: 0.2773 - accuracy: 0.8895 - val_loss: 0.1958 - val_accuracy: 0.9128
# Epoch 96/100
# 108/108 [==============================] - 8s 56ms/step - loss: 0.2821 - accuracy: 0.8825 - val_loss: 0.2469 - val_accuracy: 0.8938
# Epoch 97/100
# 108/108 [==============================] - 9s 59ms/step - loss: 0.3026 - accuracy: 0.8773 - val_loss: 0.2353 - val_accuracy: 0.9172
# Epoch 98/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.3020 - accuracy: 0.8871 - val_loss: 0.2111 - val_accuracy: 0.9033
# Epoch 99/100
# 108/108 [==============================] - 9s 60ms/step - loss: 0.3031 - accuracy: 0.8750 - val_loss: 0.1950 - val_accuracy: 0.9141
# Epoch 100/100
# 108/108 [==============================] - 8s 55ms/step - loss: 0.2974 - accuracy: 0.8831 - val_loss: 0.1773 - val_accuracy: 0.9271

# %%
model.save('CNNModel_Corn_v5.h5')

# %%
modelname = "CNNModel_Corn_Save5"
save_all_model(modelname, model, history)
# Out:
# INFO:tensorflow:Assets written to: saved_model\CNNModel_Corn_Save5\assets
# Export path:  saved_model\CNNModel_Corn_Save5
# ['assets', 'keras_metadata.pb', 'saved_model.pb', 'variables']

# %%
score_train = model.evaluate(train_ds)
score_valid = model.evaluate(val_ds)
score_test = model.evaluate(test_ds)
# Out:
# 108/108 [==============================] - 3s 11ms/step - loss: 0.1848 - accuracy: 0.9281
# 20/20 [==============================] - 3s 16ms/step - loss: 0.1972 - accuracy: 0.9250
# 7/7 [==============================] - 3s 20ms/step - loss: 0.2204 - accuracy: 0.9196

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
print("Accuracy: {}".format(acc[-1]))
print("Validation Accuracy: {}".format(val_acc[-1]))

print("Loss: {}".format(loss[-1]))
print("Validation Loss: {}".format(val_loss[-1]))
# Out:
# Accuracy: 0.8830867409706116
# Validation Accuracy: 0.9270998239517212
# Loss: 0.2974313795566559
# Validation Loss: 0.177251935005188

# %%
epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training Accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
plt.plot(epochs, loss, 'r', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and Validation Loss')
plt.legend(loc=0)
plt.figure()

plt.show()

# %%
plt.figure(figsize=(6, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
#plt.ylim([min(plt.ylim()),1])
plt.ylim([0,1.0])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Cross Entropy')
plt.ylim([0,1.0])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("actual label:",classes[first_label])
    
    batch_prediction = model.predict(images_batch)
    print("predicted label:",classes[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# actual label: corn NorthernLeaf Blight
# predicted label: corn NorthernLeaf Blight

# %%
def predict(model,img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) # Create a batch
    predictions = model.predict (img_array)
    predicted_class = classes[np.argmax(predictions[0])]
#     confidence = round(np.max(predictions[0]),2)
    confidence = round(100*(np.max(predictions[0])),2)

    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images,labels in test_ds.take(1):
    for i in range(12):
        ax = plt.subplot(3,4,i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class , confidence = predict(model,images[i].numpy())
        actual_class = classes[labels[i]]
        
        plt.title(f"Actual: {actual_class},\n Predicted: {predicted_class},\n Confidence Score: {confidence}%")
        plt.axis("off")

# %%
pred_class = []
act_class = []
for images,labels in test_ds:
    for i in range(len(test_ds)):
        #ax = plt.subplot(3,4,i+1)
        #plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class , confidence = predict(model,images[i].numpy())
        actual_class = classes[labels[i]]

        pred_class.append(predicted_class)
        act_class.append(actual_class)

# %%
act_class
# Out:
# ['corn healthy',
#  'corn healthy',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn Common Rust',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn Common Rust',
#  'corn Common Rust',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn healthy',
#  'corn Leaf Gray Leaf Spot',
#  'corn Leaf Gray Leaf Spot',
#  'corn Leaf Gray Leaf Spot',
#  'corn Leaf Gray Leaf Spot',
#  'corn healthy',
#  'corn Leaf Gray Leaf Spot',
#  'corn Leaf Gray Leaf Spot',
#  'corn Common Rust',
#  'corn healthy',
#  'corn NorthernLeaf Blight',
#  'corn Common Rust',
#  'corn Leaf Gray Leaf Spot',
#  'corn Common Rust',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn Common Rust',
#  'corn Common Rust',
#  'corn healthy',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight',
#  'corn Leaf Gray Leaf Spot',
#  'corn NorthernLeaf Blight',
#  'corn NorthernLeaf Blight']

# %%
cm = confusion_matrix(act_class, pred_class, labels=classes)

# %%
def plot_confusion_matrix(cm, classes):
    ax = sns.heatmap(cm, annot=True, fmt='g', cmap='Blues')
    ax.set_title('Confusion Matrix with labels\n');
    ax.set_xlabel('\nPredicted Values')
    ax.set_ylabel('Actual Values ');

    ax.xaxis.set_ticklabels(classes, rotation=45)
    ax.yaxis.set_ticklabels(classes, rotation=45)

# %%
plot_confusion_matrix(cm = cm, classes = classes)

# %%
plot_confusion_matrix(cm, classes= classes)
# Out:
# [[ 8  0  0  0]
#  [ 0 13  2  0]
#  [ 0  1 19  0]
#  [ 0  0  0  6]]

# %%
len(test_ds) * BATCH_SIZE
# Out:
# 224

# %%
tf.math.confusion_matrix(
    labels = act_class,
    predictions = pred_class,
    num_classes = 4
)
# Out:
# ---------------------------------------------------------------------------
# UnimplementedError                        Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 tf.math.confusion_matrix(
#       2     labels = act_class,
#       3     predictions = pred_class,
#       4     num_classes = 4
#       5 )
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\confusion_matrix.py:158, in confusion_matrix(labels, predictions, num_classes, weights, dtype, name)
#     152 with ops.name_scope(name, 'confusion_matrix',
#     153                     (predictions, labels, num_classes, weights)) as name:
#     154   labels, predictions = remove_squeezable_dimensions(
#     155       ops.convert_to_tensor(labels, name='labels'),
#     156       ops.convert_to_tensor(
#     157           predictions, name='predictions'))
# --> 158   predictions = math_ops.cast(predictions, dtypes.int64)
#     159   labels = math_ops.cast(labels, dtypes.int64)
#     161   # Sanity checks - underflow or overflow can cause memory corruption.
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\util\dispatch.py:206, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     204 """Call target, and fall back on dispatchers if there is a TypeError."""
#     205 try:
# --> 206   return target(*args, **kwargs)
#     207 except (TypeError, ValueError):
#     208   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     209   # TypeError, when given unexpected types.  So we need to catch both.
#     210   result = dispatch(wrapper, args, kwargs)
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\math_ops.py:990, in cast(x, dtype, name)
#     988   x = ops.convert_to_tensor(x, name="x")
#     989   if x.dtype.base_dtype != base_type:
# --> 990     x = gen_math_ops.cast(x, base_type, name=name)
#     991 if x.dtype.is_complex and base_type.is_floating:
#     992   logging.warn("Casting complex to real discards imaginary part.")
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:1942, in cast(x, DstT, Truncate, name)
#    1940   return _result
#    1941 except _core._NotOkStatusException as e:
# -> 1942   _ops.raise_from_not_ok_status(e, name)
#    1943 except _core._FallbackException:
#    1944   pass
#
# File c:\Users\marie\anaconda3\envs\tensorflow\lib\site-packages\tensorflow\python\framework\ops.py:6941, in raise_from_not_ok_status(e, name)
#    6939 message = e.message + (" name: " + name if name is not None else "")
#    6940 # pylint: disable=protected-access
# -> 6941 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# UnimplementedError: Cast string to int64 is not supported [Op:Cast]

# %%
y_val = val_ds.classes
y_pred_val = model.predict(val_ds)
y_pred_val = tf.argmax(y_pred_val, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 y_val = val_ds.classes
#       2 y_pred_val = model.predict(val_ds)
#       3 y_pred_val = tf.argmax(y_pred_val, axis=1)
#
# AttributeError: 'TakeDataset' object has no attribute 'classes'

# %%
# Compute confusion matrix
cm = confusion_matrix(y_val, y_pred_val)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=90)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Show the confusion matrix
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 2
#       1 # Compute confusion matrix
# ----> 2 cm = confusion_matrix(y_val, y_pred_val)
#       4 # Plot confusion matrix
#       5 plt.figure(figsize=(10, 8))
#
# NameError: name 'y_val' is not defined

# %%
y_test = test_dataset.classes
y_pred_test = model.predict(test_dataset)
y_pred_test = tf.argmax(y_pred_test, axis=1)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred_test)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = np.arange(len(classes))
plt.xticks(tick_marks, classes, rotation=90)
plt.yticks(tick_marks, classes)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Show the confusion matrix
plt.show()
