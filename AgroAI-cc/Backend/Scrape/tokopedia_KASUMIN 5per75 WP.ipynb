# %%
import requests
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'

# %%
payload = [{
    'operationName': "SearchProductQueryV4",
    'variables': {
        "params": "device=desktop&navsource=&ob=23&page={}&q={}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=330142c9d1c168eaabef95522c06e1fa&user_addressId=44389028&user_cityId=167&user_districtId=2202&user_id=24265242&user_lat=-6.218126229670426&user_long=107.01841201633215&user_postCode=17123&user_warehouseId=12941747&variants=&warehouses=12941747%232h%2C0%2315m"
        },
    'query': "query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
}]

# %%
operationName
: 
"SearchProductQueryV4"
query
: 
"query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
variables
: 
{,…}
params
: 
"device=desktop&navsource=&ob=23&page=1&q=KASUMaIN%205%2F75%20WP&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start=0&topads_bucket=true&unique_id=330142c9d1c168eaabef95522c06e1fa&user_addressId=44389028&user_cityId=167&user_districtId=2202&user_id=24265242&user_lat=-6.218126229670426&user_long=107.01841201633215&user_postCode=17123&user_warehouseId=12941747&variants=&warehouses=12941747%232h%2C0%2315m"

# %%
req = requests.post(url, json=payload).json()
rows = req[0]['data']['ace_search_product_v4']['data']['products']
print(len(rows))
# Out:
# 60

# %%
print(req)
# Out:
# [{'data': {'ace_search_product_v4': {'header': {'totalData': 13897010, 'totalDataText': '13.7jt+', 'processTime': 0.37908494800000003, 'responseCode': 6, 'errorMessage': '', 'additionalParams': 'rf=true&nuq=ac', 'keywordProcess': '7', 'componentId': '02.01.00.00', '__typename': 'AceSearchUnifyHeader'}, 'data': {'banner': {'position': 0, 'text': '', 'imageUrl': '', 'url': '', 'componentId': '', 'trackingOption': 0, '__typename': 'AceSearchUnifyBanner'}, 'backendFilters': '&ob=104', 'isQuerySafe': True, 'ticker': {'text': '', 'query': '', 'typeId': 0, 'componentId': '', 'trackingOption': 0, '__typename': 'AceSearchUnifyTicker'}, 'redirection': {'redirectUrl': '', 'departmentId': 0, '__typename': 'AceSearchUnifyRedirection'}, 'related': {'position': 0, 'trackingOption': 0, 'relatedKeyword': 'ac', 'otherRelated': [], '__typename': 'AceSearchUnifyRelated'}, 'suggestion': {'currentKeyword': '{}', 'suggestion': 'ac', 'suggestionCount': 13899719, 'instead': '', 'insteadCount': 0, 'query': '', 'text': 'Tidak dapat menemukan hasil untuk <strong>"{}"</strong>. Menampilkan hasil untuk <strong><font color="#42b549">"ac"</font></strong>', 'componentId': '03.08.01.00', 'trackingOption': 3, '__typename': 'AceSearchUnifySuggestion'}, 'products': [{'id': 1988491712, 'name': 'AC SAMSUNG 1/2 PK STANDARD AR05TGHQASINSE', 'ads': {'adsId': '', 'productClickUrl': '', 'productWishlistUrl': '', 'productViewUrl': '', '__typename': 'AceSearchUnifyAds'}, 'badges': [{'title': 'Official Store', 'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png', 'show': True, '__typename': 'AceSearchUnifyBadge'}], 'category': 3935, 'categoryBreadcrumb': 'elektronik/alat-pendingin-ruangan/air-conditioner', 'categoryId': 60, 'categoryName': 'Elektronik', 'countReview': 138, 'customVideoURL': '', 'discountPercentage': 34, 'gaKey': '/searchproduct/elektronik/alat-pendingin-ruangan/air-conditioner/%7B%7D/courtselektronik/ac-samsung-1-2-pk-standard-ar05tghqasinse', 'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/VqbcmM/2021/7/9/ffc841c4-93e0-4037-8e8d-100eac271ef8.jpg', 'labelGroups': [{'position': 'price', 'title': 'Cashback', 'type': 'lightGreen', 'url': '', '__typename': 'AceSearchUnifyLabelGroup'}, {'position': 'integrity', 'title': 'Terjual 250+', 'type': 'textDarkGrey', 'url': '', '__typename': 'AceSearchUnifyLabelGroup'}], 'originalPrice': 'Rp4.409.000', 'price': 'Rp2.899.000', 'priceRange': '', 'rating': 5, 'ratingAverage': '4.9', 'shop': {'shopId': 7015069, 'name': 'Courts Elektronik', 'url': 'https://www.tokopedia.com/courtselektronik', 'city': 'Bekasi', 'isOfficial': True, 'isPowerBadge': True, '__typename': 'AceSearchUnifyShop'}, 'url': 'https://www.tokopedia.com/courtselektronik/ac-samsung-1-2-pk-standard-ar05tghqasinse?extParam=ivf%3Dfalse%26src%3Dsearch&refined=true', 'wishlist': False, 'sourceEngine': '0', '__typename': 'AceSearchUnifyProduct'}, {'id': 1627442770, 'name': 'LG AC STANDART H05TN4 H05-TN4 [1/2 PK] GARANSI RESMI', 'ads': {'adsId': '', 'productClickUrl': '', 'productWishlistUrl': '', 'productViewUrl': '', '__typename': 'AceSearchUnifyAds'}, 'badges': [{'title': 'Official Store', 'imageUrl': 'https://images.tokopedia.net/img/official_store_badge.png', 'show': True, '__typename': 'AceSearchUnifyBadge'}], 'category': 3935, 'categoryBreadcrumb': 'elektronik/alat-pendingin-ruangan/air-conditioner', 'categoryId': 60, 'categoryName': 'Elektronik', 'countReview': 160, 'customVideoURL': 'https://vod.tokopedia.com/view/adaptive.m3u8?id=72858eb07ded71edbfa62680f9ea0102', 'discountPercentage': 2, 'gaKey': '/searchproduct/elektronik/alat-pendingin-ruangan/air-conditioner/%7B%7D/verry-lie/lg-ac-standart-h05tn4-h05-tn4-1-2-pk-garansi-resmi', 'imageUrl': 'https://images.tokopedia.net/img/cache/200-square/hDjmkQ/2022/3/28/5f871254-dee3-4d39-ae49-1de4ce6fa47f.jpg', 'labelGroups': [{'position': 'price', 'title': 'Cashback', 'type': 'lightGreen', 'url': '', '__typename': 'AceSearchUnifyLabelGroup'}, {'position': 'integrity', 'title': 'T ...

# %%
for i in range(0, len(rows)):
    no = i
    nama_produk = rows[i]['name']
    harga = rows[i]['price']
    rating = rows[i]['ratingAverage']
    toko = rows[i]['shop']['name']
    lokasi = rows[i]['shop']['city']
    tjl = rows[i]['labelGroups']
    terjual = ''
    for i in tjl:
        if tjl[0]['position'] == 'costperunit':
            terjual = ''
        elif tjl[0]['title'] == 'PreOrder':
            terjual = ''
        elif tjl[0]['title'] == 'Grosir':
            terjual = ''
        elif tjl[0]['title'] == 'Produk Terbaru':
            terjual = ''
        elif tjl[0]['title'] =='Cashback':
            terjual = ''
        else:
            terjual = tjl[0]['title']
    #terjual = next((rows[i]['labelGroups'][0]['title'] for item in rows[i]['labelGroups'][0] if rows[i]['labelGroups'][0]['position'] == 'integrity'), None)
    print(no, nama_produk, harga, rating, toko, lokasi, terjual)
# Out:
# 0 AC SAMSUNG 1/2 PK STANDARD AR05TGHQASINSE Rp2.899.000 4.9 Courts Elektronik Bekasi
# 1 LG AC STANDART H05TN4 H05-TN4 [1/2 PK] GARANSI RESMI Rp2.499.401 4.9 sinar agung electronic Kab. Bekasi
# 2 modul Ac universal Rp95.000 5.0 karya teknik ac Bekasi
# 3 promo ac watt rendah dingin second 1/2 pk ,3/4 pk,1pk Rp1.915.000 4.8 SETIATEKNIK07 Bekasi Terjual 250+
# 4 AC AQUA AQA- 5AHR1 1/2 PK Harga Unit Only Rp2.149.000 4.8 COOLING CENTER Jakarta Timur Terlaris
# 5 AC DAIKIN FTP 25 AV14 RV 1 PK + PASANG R32 STANDARD MALAYSIA LOW WATT Rp3.773.500 4.8 MJ GROSIR ELEKTRONIK Bekasi
# 6 AC DAIKIN FTP 15 AV14 0.5 PK 1/2PK + PASANG R32 STANDARD MALAYSIA LOW Rp3.479.500 4.8 MJ GROSIR ELEKTRONIK Bekasi
# 7 termis/thermistor ac daikin tipe FTC /FTKQ ori daikin Rp99.999 4.9 karya teknik ac Bekasi Terjual 70+
# 8 Outdoor AC Sharp UK 1/2 Pk tipe 05 UCY Rp1.400.000 4.9 karya teknik ac Bekasi Sisa 2
# 47 DAIKIN FTP25AV14 AC Standart BREEZE 1PK MALAYSIA Rp3.335.000 5.0 OneStop Electronics Jakarta Utara
# 48 PLASTIK CUCI AC KECIL / AC CLEANING COVER 0.5-1 PK Rp20.000 4.9 Ultra 2000 Jakarta Pusat
# 49 SHARP AH-A12SAY AC Split Standard R32 1.5PK Thailand Rp4.625.000 5.0 OneStop Electronics Jakarta Utara
# 50 AC Panasonic CS-LN12WKJ si-BiRU - Standard low watt 1.5PK 1.5 PK - R32 Rp5.199.000 5.0 Permata Elektronik Jakarta Pusat
# 51 AC DAIKIN FTC35NV14 - Standard Thailand 1.5 PK - R32 Rp5.459.000 5.0 TDS AC Shop Jakarta Barat Sisa 8
# 52 Extreme Ultra AC Bocor Halus Rp425.000 5.0 Big-Mart Jakarta Utara Terjual 100+
# 53 AC DAIKIN FLASH INVERTER 1,5PK FTKQ35 Rp6.609.000 5.0 INDO COOL Jakarta Barat
# 54 Outdoor ac Sharp 1 pk Thailand tipe 09 say Rp1.850.000 4.9 karya teknik ac Bekasi Terjual 60+
# 55 Gree AC Standard 3/4 pk GWC-07MOO5 Unit Only :: 07 MOO5 Rp3.499.000 5.0 89 elektronik Jakarta Barat
# 56 AC Split 1PK HISENSE AN09CDG R32 1PK - AN-09CDG - AN09CDG Rp2.770.000 5.0 Putra Jaya 88 Jakarta Timur
# 57 plastik cuci ac/terpal cuci ac split /bahan ok banget Rp80.000 5.0 toko terpal jaya abadi Kab. Bekasi Terjual 100+
# 58 Termis/thermis/thermistor ac panasonic Rp8.500 4.9 karya teknik ac Bekasi
# 59 AC SPLIT DAIKIN FTC-35NV14 (New Thailand) 1.5 PK Standard UNIT ONLY Rp5.459.000 5.0 Captain Air Conditioning Jakarta Utara Terjual 250+

# %%
len(terjual)
# Out:
# 12

# %%
search = 'KASUMIN 5/75 WP'
url = 'https://gql.tokopedia.com/graphql/SearchProductQueryV4'

def get_param():
    params = []
    for i in range(1,27):
        param = "device=desktop&navsource=&ob=23&page={}&q={}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=330142c9d1c168eaabef95522c06e1fa&user_addressId=44389028&user_cityId=167&user_districtId=2202&user_id=24265242&user_lat=-6.218126229670426&user_long=107.01841201633215&user_postCode=17123&user_warehouseId=12941747&variants=&warehouses=12941747%232h%2C0%2315m".format(i, search, (i-1)*60)
        params.append(param)

    return params

def scraped(param):
    payload = [{
    'operationName': "SearchProductQueryV4",
    'variables': {
        "params": param
        },
    'query': "query SearchProductQueryV4($params: String!) {\n  ace_search_product_v4(params: $params) {\n    header {\n      totalData\n      totalDataText\n      processTime\n      responseCode\n      errorMessage\n      additionalParams\n      keywordProcess\n      componentId\n      __typename\n    }\n    data {\n      banner {\n        position\n        text\n        imageUrl\n        url\n        componentId\n        trackingOption\n        __typename\n      }\n      backendFilters\n      isQuerySafe\n      ticker {\n        text\n        query\n        typeId\n        componentId\n        trackingOption\n        __typename\n      }\n      redirection {\n        redirectUrl\n        departmentId\n        __typename\n      }\n      related {\n        position\n        trackingOption\n        relatedKeyword\n        otherRelated {\n          keyword\n          url\n          product {\n            id\n            name\n            price\n            imageUrl\n            rating\n            countReview\n            url\n            priceStr\n            wishlist\n            shop {\n              city\n              isOfficial\n              isPowerBadge\n              __typename\n            }\n            ads {\n              adsId: id\n              productClickUrl\n              productWishlistUrl\n              shopClickUrl\n              productViewUrl\n              __typename\n            }\n            badges {\n              title\n              imageUrl\n              show\n              __typename\n            }\n            ratingAverage\n            labelGroups {\n              position\n              type\n              title\n              url\n              __typename\n            }\n            componentId\n            __typename\n          }\n          componentId\n          __typename\n        }\n        __typename\n      }\n      suggestion {\n        currentKeyword\n        suggestion\n        suggestionCount\n        instead\n        insteadCount\n        query\n        text\n        componentId\n        trackingOption\n        __typename\n      }\n      products {\n        id\n        name\n        ads {\n          adsId: id\n          productClickUrl\n          productWishlistUrl\n          productViewUrl\n          __typename\n        }\n        badges {\n          title\n          imageUrl\n          show\n          __typename\n        }\n        category: departmentId\n        categoryBreadcrumb\n        categoryId\n        categoryName\n        countReview\n        customVideoURL\n        discountPercentage\n        gaKey\n        imageUrl\n        labelGroups {\n          position\n          title\n          type\n          url\n          __typename\n        }\n        originalPrice\n        price\n        priceRange\n        rating\n        ratingAverage\n        shop {\n          shopId: id\n          name\n          url\n          city\n          isOfficial\n          isPowerBadge\n          __typename\n        }\n        url\n        wishlist\n        sourceEngine: source_engine\n        __typename\n      }\n      violation {\n        headerText\n        descriptionText\n        imageURL\n        ctaURL\n        ctaApplink\n        buttonText\n        buttonType\n        __typename\n      }\n      __typename\n    }\n    __typename\n  }\n}\n"
    }]

    req = requests.post(url, json=payload).json()
    rows = req[0]['data']['ace_search_product_v4']['data']['products']
    #print(len(rows))
    scraped = []
    for i in range(0, len(rows)):
        no = i
        toko = rows[i]['shop']['name']
        lokasi = rows[i]['shop']['city']
        nama_produk = rows[i]['name']
        harga = rows[i]['price']
        rating = rows[i]['ratingAverage']
        tjl = rows[i]['labelGroups']
        terjual = ''
        for i in tjl:
            if tjl[0]['position'] == 'costperunit':
                terjual = ''
            elif tjl[0]['title'] == 'PreOrder':
                terjual = ''
            elif tjl[0]['title'] == 'Grosir':
                terjual = ''
            elif tjl[0]['title'] == 'Produk Terbaru':
                terjual = ''
            elif tjl[0]['title'] =='Cashback':
                terjual = ''
            else:
                terjual = tjl[0]['title']
        scraped.append((
            nama_produk, harga, rating, toko, lokasi, terjual
        ))
    return scraped

if __name__ == '__main__':
    params = get_param()
    all_data = []
    for i in range(0, len(params)):
        param = params[i]
        data = scraped(param)
        all_data.extend(data)
    #print(all_data)
    df_KASUMIN = pd.DataFrame(all_data, columns=['Nama Produk', 'Harga', 'Rating', 'Toko', 'Lokasi', 'Terjual'])

# %%
#params_all = "device=desktop&navsource=&ob=23&page={}&q={}&related=true&rows=60&safe_search=false&scheme=https&shipping=&source=search&srp_component_id=02.01.00.00&srp_page_id=&srp_page_title=&st=product&start={}&topads_bucket=true&unique_id=330142c9d1c168eaabef95522c06e1fa&user_addressId=44389028&user_cityId=167&user_districtId=2202&user_id=24265242&user_lat=-6.218126229670426&user_long=107.01841201633215&user_postCode=17123&user_warehouseId=12941747&variants=&warehouses=12941747%232h%2C0%2315m".format(page, start)

# %%
df_KASUMIN
# Out:
#                                            Nama Produk      Harga Rating  \
# 0    Kasumin 5/75 Wp 500gr Bakterisida Yg Mampu Men...   Rp33.000    5.0
# 1    Fungisida tembaga oksiklorida KASUMIN 5/75 WP ...   Rp52.000    4.4
# 2    Sale Kasumin 5/75 wp anti Bakteri dan Jamur 50...   Rp32.000
# 3    Fungisida/Bakterisida Kasumin 5/75 wp anti Bak...   Rp36.000    5.0
# 4    Fungisida KASUMIN 5/75 WP isi 500 gr dari INDAGRO   Rp38.480    5.0
# ..                                                 ...        ...    ...
# 112  Sale Kasumin 5 75 wp i Bakteri dan Jur gr Oril...   Rp74.000
# 113                 KASUMIN 5/75 WP 500 GR | FUNGISIDA   Rp40.800
# 114  Sale Kasumin 5/75 Wp Anti Bakteri Dan Jamur 50...   Rp46.000
# 115  fungisida bakterisida kasumin 5/75 wp kasugami...  Rp179.000
# 116  Fungisida Plus Bakterisida Sistemik - KASUMIN ...  Rp133.000    1.0
#
#                   Toko         Lokasi       Terjual
# 0        Srikandi Tani    Kab. Kediri  Terjual 100+
# 1    MITRA_TANI_SUKSES    Kab. Kediri     Terjual 9
# 2           Firda Tani    Kab. Kediri
# 3     11Pin_Tani Store    Kab. Kediri
# 4       tokosuksestani    Kab. Kediri
# ..                 ...            ...           ...
# 112       BharrataShop       Denpasar
# 113      Kampoeng Tani     Kab. Tuban
# 114         ADUDU HOME  Jakarta Pusat
# 115    TOKO MAJU JAYAQ  Kab. Sukabumi
# 116       undatus shop       Semarang     Terjual 1
#
# [117 rows x 6 columns]

# %%
df_KASUMIN['Terjual'].unique()
# Out:
# array(['Terjual 100+', 'Terjual 9', '', 'Diskon', 'Terjual 4',
#        'Terjual 10', 'Terjual 1'], dtype=object)

# %%
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 1', 'Terjual_num1'] = '1'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 2', 'Terjual_num1'] = '2'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 3', 'Terjual_num1'] = '3'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 4', 'Terjual_num1'] = '4'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 5', 'Terjual_num1'] = '5'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 6', 'Terjual_num1'] = '6'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 7', 'Terjual_num1'] = '7'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 8', 'Terjual_num1'] = '8'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 9', 'Terjual_num1'] = '9'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 10', 'Terjual_num1'] = '10'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 11', 'Terjual_num1'] = '11'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 12', 'Terjual_num1'] = '12'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 13', 'Terjual_num1'] = '13'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 15', 'Terjual_num1'] = '15'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 16', 'Terjual_num1'] = '16'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 18', 'Terjual_num1'] = '18'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 19', 'Terjual_num1'] = '19'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 20', 'Terjual_num1'] = '20'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 21', 'Terjual_num1'] = '21'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 22', 'Terjual_num1'] = '22'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 24', 'Terjual_num1'] = '24'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 25', 'Terjual_num1'] = '25'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 28', 'Terjual_num1'] = '28'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 30+', 'Terjual_num1'] = '30'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 50+', 'Terjual_num1'] = '50'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 60+', 'Terjual_num1'] = '60'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 80+', 'Terjual_num1'] = '80'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 250+', 'Terjual_num1'] = '250'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 500+', 'Terjual_num1'] = '500'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 750+', 'Terjual_num1'] = '750'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 1 rb+', 'Terjual_num1'] = '1000'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 3 rb+', 'Terjual_num1'] = '3000'
df_KASUMIN.loc[df_KASUMIN['Terjual'] == 'Terjual 4 rb+', 'Terjual_num1'] = '4000'

# %%
df_KASUMIN['Terjual_num1'] = df_KASUMIN['Terjual_num1'].astype(float)

# %%
df_KASUMIN['Rating'] = df_KASUMIN['Rating'].replace('', np.nan, regex=True)
df_KASUMIN['Rating'] = df_KASUMIN['Rating'].astype(float)

# %%
df_KASUMIN['Harga'] = df_KASUMIN['Harga'].str.replace(r'\D', '')
# Out:
# C:\Users\i_fes\AppData\Local\Temp\ipykernel_19320\1479933570.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_KASUMIN['Harga'] = df_KASUMIN['Harga'].str.replace(r'\D', '')

# %%
df_KASUMIN['Harga'] = df_KASUMIN['Harga'].astype(float)

# %%
df_KASUMIN.dtypes
# Out:
# Nama Produk      object
# Harga           float64
# Rating          float64
# Toko             object
# Lokasi           object
# Terjual          object
# Terjual_num1    float64
# dtype: object

# %%
ax = df_KASUMIN['Lokasi'].value_counts() \
    .plot(kind= 'barh', figsize = (12,6), title='Rata-Rata Toko Online Berdasarkan Lokasi (Aneka KASUMIN)')

plt.ticklabel_format(style='plain', axis='x')

ax.bar_label(ax.containers[0], label_type = 'edge', fmt = '%d', fontsize = 12)

plt.show()

# %%
ax = df_KASUMIN.groupby('Lokasi')['Terjual_num1'].mean().sort_values(ascending=False) \
    .plot(kind= 'barh', figsize = (12,6), title='Rata-Rata Penjualan Berdasarkan Lokasi (Aneka KASUMIN)')
ax.bar_label(ax.containers[0], label_type = 'center', fmt = '%d', fontsize=12)
plt.show()

# %%
df_KASUMIN['Pendapatan'] = df_KASUMIN['Terjual_num1']*df_KASUMIN['Harga']
my_colors = list('bbgbb')

ax = df_KASUMIN.groupby('Lokasi')['Pendapatan'].mean().sort_values(ascending=False) \
    .plot(kind= 'barh', figsize = (16,8), title='Rata-Rata Pendapatan Berdasarkan Lokasi (Aneka KASUMIN)', color=my_colors)
plt.ticklabel_format(style='plain', axis='x')

ax.bar_label(ax.containers[0], label_type = 'edge', fmt = '%d', fontsize=12)
for spine in ax.spines:
    ax.spines[spine].set_visible(False)

#rects = ax.patches

#labels = [f"label{i}" for i in range(len(rects))]


#for rect, label in zip(rects, labels):
#    height = rect.get_height()
#    ax.text(
#        rect.get_x() + rect.get_width() / 2, height + 5, label, ha="center", va="bottom"
#    )

plt.show()

# %%
df_corr = df_KASUMIN.dropna().corr()
sns.heatmap(df_corr, annot = True)
# Out:
# C:\Users\i_fes\AppData\Local\Temp\ipykernel_19320\2985848494.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_corr = df_KASUMIN.dropna().corr()
# <Axes: >

# %%
#df_Abamektin.to_excel('Tokped_Daging_API.xlsx', index=False)
